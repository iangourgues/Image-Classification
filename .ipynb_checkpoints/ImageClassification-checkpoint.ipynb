# %%
import tensorflow as tf
import os

# %%
gpus = tf.config.experimental.list_physical_devices('CPU')

# %%
gpus
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
import cv2
import imghdr
from matplotlib import pyplot as plt
import numpy as np

# %%
data_dir = 'data'

# %%
image_exts = ['jpeg', 'jpg', 'bmp', 'png']

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try:
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts:
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e:
            print('Issue with image {}'.format(image_path))

# %%
data = tf.keras.utils.image_dataset_from_directory('data')
# Out:
# Found 479 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
# Get batch from iterator
batch = data_iterator.next()

# %%
batch[0].shape
# Out:
# (32, 256, 256, 3)

# %%
#Preprocess Data

# %%
data = data.map(lambda x, y: (x/255, y))

# %%
scaled_iterator = data.as_numpy_iterator()

# %%
batch = scaled_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(batch[1][idx])

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)+1
test_size = int(len(data)*.1)+1

# %%
train_size+val_size+test_size
# Out:
# 16

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
len(test)
# Out:
# 1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3, 3), activation='relu', input_shape=(256, 256, 3)))
model.add(MaxPooling2D())

model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16, (3,3), activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)                   │ (None, 254, 254, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 127, 127, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 125, 125, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 62, 62, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 60, 60, 16)          │           4,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 30, 30, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 14400)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │       3,686,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,696,625 (14.10 MB)
#  Trainable params: 3,696,625 (14.10 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Training the Data

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 544ms/step - accuracy: 0.4787 - loss: 1.7400 - val_accuracy: 0.4844 - val_loss: 0.7047
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 570ms/step - accuracy: 0.5628 - loss: 0.6874 - val_accuracy: 0.7266 - val_loss: 0.6559
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 552ms/step - accuracy: 0.7332 - loss: 0.6355 - val_accuracy: 0.6484 - val_loss: 0.6210
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 555ms/step - accuracy: 0.7419 - loss: 0.5344 - val_accuracy: 0.7578 - val_loss: 0.5092
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 562ms/step - accuracy: 0.6954 - loss: 0.5800 - val_accuracy: 0.8438 - val_loss: 0.4778
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 561ms/step - accuracy: 0.8099 - loss: 0.4726 - val_accuracy: 0.6562 - val_loss: 0.6098
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 576ms/step - accuracy: 0.7934 - loss: 0.4657 - val_accuracy: 0.7031 - val_loss: 0.5291
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 580ms/step - accuracy: 0.7561 - loss: 0.4866 - val_accuracy: 0.8359 - val_loss: 0.4258
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 570ms/step - accuracy: 0.8133 - loss: 0.4109 - val_accuracy: 0.8047 - val_loss: 0.4322
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 578ms/step - accuracy: 0.8519 - loss: 0.3860 - val_accuracy: 0.8281 - val_loss: 0.4169
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 577ms/step - accuracy: 0.8660 - loss: 0.3263 - val_accuracy: 0.9375 - val_loss: 0.2005
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 564ms/step - accuracy: 0.8931 - loss: 0.2770 - val_accuracy: 0.8906 - val_loss: 0.2580
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 561ms/step - accuracy: 0.8904 - loss: 0.2910 - val_accuracy: 0.8906 - val_loss: 0.2930
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 578ms/step - accuracy: 0.9110 - loss: 0.2545 - val_accuracy: 0.9141 - val_loss: 0.2564
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 563ms/step - accuracy: 0.9403 - loss: 0.2185 - val_accuracy: 0.9219 - val_loss: 0.1869
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 562ms/step - accuracy: 0.9493 - loss: 0.1654 - val_accuracy: 0.8516 - val_loss: 0.2923
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 564ms/step - accuracy: 0.9547 - loss: 0.1376 - val_accuracy: 0.9609 - val_loss: 0.1322
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 565ms/step - accuracy: 0.9581 - loss: 0.1417 - val_accuracy: 0.9844 - val_loss: 0.0799
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 568ms/step - accuracy: 0.9817 - loss: 0.0845 - val_accuracy: 0.9844 - val_loss: 0.0631
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 567ms/step - accuracy: 0.9945 - loss: 0.0549 - val_accuracy: 0.9844 - val_loss: 0.0560

# %%
#Plotting performance

# %%
fig, ax = plt.subplots()
ax.plot(hist.history['loss'], color='blue', label='loss')
ax.plot(hist.history['val_loss'], color='green', label='val_loss')
fig.suptitle('Loss', fontsize=20)
ax.legend(loc="upper left")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(hist.history['accuracy'], color='blue', label='loss')
ax.plot(hist.history['val_accuracy'], color='green', label='val_loss')
fig.suptitle('Accuracy', fontsize=20)
ax.legend(loc="upper left")
plt.show()

# %%
#Performance Evaluation

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step

# %%
print(f'Precision:{pre.result().numpy()}, Recall:{re.result().numpy()}, Accuracy:{acc.result().numpy()}')
# Out:
# Precision:1.0, Recall:1.0, Accuracy:1.0

# %%
#Testing

# %%
img = cv2.imread('Man.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %%
resize.shape
# Out:
# TensorShape([256, 256, 3])

# %%
np.expand_dims(resize, 0).shape
# Out:
# (1, 256, 256, 3)

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
yhat
# Out:
# array([[0.8733709]], dtype=float32)

# %%
if yhat > .5:
    print(f'Predicted class is Person')
else:
    print(f'Predicted class is Animal')
# Out:
# Predicted class is Person

# %%
#Final Build
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','animalhumanmodel.h5'))
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
new_model = load_model(os.path.join('models', 'animalhumanmodel.h5'))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
yhatnew = new_model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step

# %%
if yhatnew > .5:
    print(f'Predicted class is Person')
else:
    print(f'Predicted class is Animal')
# Out:
# Predicted class is Person
